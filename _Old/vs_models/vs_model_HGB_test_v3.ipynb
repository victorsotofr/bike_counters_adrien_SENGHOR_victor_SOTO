# %%
import utils
import pandas as pd
import numpy as np
from vs_feature_eng import feature_eng_v3

# %%
X, y = utils.get_train_data()

# %%
train_data = pd.read_parquet('data/train.parquet')
train_data = feature_eng_v3._merge_external_data(train_data)
train_data.select_dtypes(exclude=['category']).corr()['log_bike_count']
# Out:
# site_id                      0.020998
# bike_count                   0.738168
# date                         0.044621
# counter_installation_date    0.118209
# latitude                     0.113355
# longitude                    0.044494
# log_bike_count               1.000000
# t                            0.299766
# cl                           0.037632
# tend24                       0.014070
# etat_sol                    -0.094691
# rr3                         -0.022647
# w1                          -0.019882
# nbas                        -0.011700
# nnuage1                     -0.075017
# w2                          -0.024153
# n                            0.005702
# raf10                        0.151816
# ht_neige                     0.003080
# ssfrai                      -0.030301
# rr12                        -0.056783
# rr24                        -0.050975
# Name: log_bike_count, dtype: float64

# %%
train_data.select_dtypes(exclude=['category']).corr()['log_bike_count'].abs().nlargest(15)
# Out:
# log_bike_count               1.000000
# bike_count                   0.738168
# t                            0.299766
# raf10                        0.151816
# counter_installation_date    0.118209
# latitude                     0.113355
# etat_sol                     0.094691
# nnuage1                      0.075017
# rr12                         0.056783
# rr24                         0.050975
# date                         0.044621
# longitude                    0.044494
# cl                           0.037632
# ssfrai                       0.030301
# w2                           0.024153
# Name: log_bike_count, dtype: float64

# %%
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import HistGradientBoostingRegressor

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# DATA PREPROCESSING
# ==============================================================================
numeric_features = [### DATA
                    # Relative to dates
                    'year',
                    'season_sin',
                    'season_cos',
                    'month_sin',
                    'month_cos',
                    'weekday_sin',
                    'weekday_cos',
                    'hour_sin',
                    'hour_cos',
                    'is_weekend',
                    'is_holiday',
                    'is_covid',
                    # Relative to location:
                    'site_id',
                    'latitude',
                    'longitude',

                    ### EXTERNAL DATA
                    't',
                    'raf10', 
                    'etat_sol', 
                    'nnuage1', 
                    'rr12', 
                    'rr24',
                    'cl', 
                    'ssfrai', 
                    'w2'
                    ]


preprocessor = ColumnTransformer(
    [('standard-scaler', StandardScaler(), numeric_features)],
    remainder='drop'
    )

# We create the full pipeline:
model = make_pipeline(
    feature_eng_v3.FeatureEngineering(),
    preprocessor,
    HistGradientBoostingRegressor(learning_rate=0.05, max_iter=300, max_depth=10) # default values
)

# %%
### TRAIN_TEST_split and RMSE measures:
def train_test_split_temporal(X, y, delta_threshold="30 days"):
    
    cutoff_date = X["date"].max() - pd.Timedelta(delta_threshold)
    mask = (X["date"] <= cutoff_date)
    X_train, X_valid = X.loc[mask], X.loc[~mask]
    y_train, y_valid = y[mask], y[~mask]

    return X_train, y_train, X_valid, y_valid

X_train, y_train, X_valid, y_valid = train_test_split_temporal(X, y)

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('featureengineering',
#                  <vs_feature_eng.feature_eng_v3.FeatureEngineering object at 0x12c41de70>),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('standard-scaler',
#                                                   StandardScaler(),
#                                                   ['year', 'season_sin',
#                                                    'season_cos', 'month_sin',
#                                                    'month_cos', 'weekday_sin',
#                                                    'weekday_cos', 'hour_sin',
#                                                    'hour_cos', 'is_weekend',
#                                                    'is_holiday', 'is_covid',
#                                                    'site_id', 'latitude',
#                                                    'longitude', 't', 'raf10',
#                                                    'etat_sol', 'nnuage1',
#                                                    'rr12', 'rr24', 'cl',
#                                                    'ssfrai', 'w2'])])),
#                 ('histgradientboostingregressor',
#                  HistGradientBoostingRegressor(learning_rate=0.05, max_depth=10,
#                                                max_iter=300))])

# %%
from sklearn.metrics import mean_squared_error

y_train_pred = model.predict(X_train)
y_valid_pred = model.predict(X_valid)

# Calculate and print RMSE for train and validation sets
print(f"Train set, RMSE={mean_squared_error(y_train, y_train_pred, squared=False):.2f}")
print(f"Validation set, RMSE={mean_squared_error(y_valid, y_valid_pred, squared=False):.2f}")
# Out:
# Train set, RMSE=0.58
# Validation set, RMSE=0.55
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
test_set = pd.read_parquet("./data/final_test.parquet")

# %%
predictions = model.predict(test_set)

# %%
# Prepare submission
output_df = pd.DataFrame({
    'Id': test_set.index,
    'log_bike_count': predictions
})

# Format log_bike_count:
output_df['log_bike_count'] = output_df['log_bike_count'].map(lambda x: f"{x:.4f}")

# Save to CSV:
output_df.to_csv('vs_sub_full_dataset_HGB_v3.csv', index=False)
print("Predictions saved to 'vs_sub_full_dataset_HGB_v3.csv'.")
# Out:
# Predictions saved to 'vs_sub_full_dataset_HGB_v3.csv'.

# %% [markdown]
# # __OPTUNA__

# %%
import optuna

# %%
def objective(trial):
    # Suggest hyperparameters
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
    max_iter = trial.suggest_int('max_iter', 100, 500)
    max_depth = trial.suggest_int('max_depth', 3, 12)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    
    # Create a pipeline with the suggested hyperparameters
    model = make_pipeline(
        feature_eng_v3.FeatureEngineering(),
        preprocessor,
        HistGradientBoostingRegressor(
            learning_rate=learning_rate,
            max_iter=max_iter,
            max_depth=max_depth,
            min_samples_leaf=min_samples_leaf
        )
    )
    
    # Split your data into training and validation sets
    X_train, y_train, X_valid, y_valid = train_test_split_temporal(X, y)

    # Fit the model
    model.fit(X_train, y_train)
    
    # Make predictions and calculate the RMSE
    y_valid_pred = model.predict(X_valid)
    rmse = mean_squared_error(y_valid, y_valid_pred, squared=False)
    
    return rmse  # We want to minimize RMSE

# Run Optuna optimization
study = optuna.create_study(direction='minimize')  # Minimize the objective
study.optimize(objective, n_trials=100)  # Run for 100 trials

# Print the best parameters
print("Best trial:")
trial = study.best_trial

print(f"  RMSE: {trial.value}")
print("  Best hyperparameters:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# After optimization, you can use the best hyperparameters to train your final model
best_params = trial.params
final_model = make_pipeline(
    feature_eng_v3.FeatureEngineering(),
    preprocessor,
    HistGradientBoostingRegressor(
        learning_rate=best_params['learning_rate'],
        max_iter=best_params['max_iter'],
        max_depth=best_params['max_depth'],
        min_samples_leaf=best_params['min_samples_leaf']
    )
)

# Fit the final model on the full training set
final_model.fit(X_train, y_train)

# Make predictions on the validation set
y_valid_pred = final_model.predict(X_valid)

# Evaluate the model
print(f"Final validation RMSE: {mean_squared_error(y_valid, y_valid_pred, squared=False):.2f}")
# Out:
# [I 2024-12-10 18:15:15,764] A new study created in memory with name: no-name-c1508c02-afbc-4f9d-ba4f-699565770ed6
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:15:37,686] Trial 0 finished with value: 1.1213534559053844 and parameters: {'learning_rate': 0.0028791538458069455, 'max_iter': 218, 'max_depth': 4, 'min_samples_leaf': 16}. Best is trial 0 with value: 1.1213534559053844.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:16:01,494] Trial 1 finished with value: 1.074273399053178 and parameters: {'learning_rate': 0.003925243865644665, 'max_iter': 157, 'max_depth': 7, 'min_samples_leaf': 6}. Best is trial 1 with value: 1.074273399053178.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:16:15,576] Trial 2 finished with value: 0.8097040199908195 and parameters: {'learning_rate': 0.016796453947694755, 'max_iter': 197, 'max_depth': 3, 'min_samples_leaf': 12}. Best is trial 2 with value: 0.8097040199908195.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:16:33,505] Trial 3 finished with value: 1.116818111378735 and parameters: {'learning_rate': 0.004978661339320206, 'max_iter': 101, 'max_depth': 12, 'min_samples_leaf': 13}. Best is trial 2 with value: 0.8097040199908195.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:17:08,102] Trial 4 finished with value: 0.977219384582153 and parameters: {'learning_rate': 0.0022202008786986866, 'max_iter': 379, 'max_depth': 7, 'min_samples_leaf': 14}. Best is trial 2 with value: 0.8097040199908195.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:17:35,668] Trial 5 finished with value: 0.6252612350822447 and parameters: {'learning_rate': 0.01621304552594226, 'max_iter': 222, 'max_depth': 9, 'min_samples_leaf': 17}. Best is trial 5 with value: 0.6252612350822447.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:17:56,325] Trial 6 finished with value: 1.1410729868134581 and parameters: {'learning_rate': 0.002129271279816001, 'max_iter': 215, 'max_depth': 10, 'min_samples_leaf': 7}. Best is trial 5 with value: 0.6252612350822447.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:18:19,423] Trial 7 finished with value: 0.7587836277479794 and parameters: {'learning_rate': 0.021001104911779513, 'max_iter': 145, 'max_depth': 4, 'min_samples_leaf': 14}. Best is trial 5 with value: 0.6252612350822447.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:18:58,402] Trial 8 finished with value: 0.6409637771141533 and parameters: {'learning_rate': 0.008585129167214748, 'max_iter': 376, 'max_depth': 12, 'min_samples_leaf': 6}. Best is trial 5 with value: 0.6252612350822447.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:19:17,839] Trial 9 finished with value: 0.6915179628063111 and parameters: {'learning_rate': 0.016204877202457002, 'max_iter': 284, 'max_depth': 4, 'min_samples_leaf': 4}. Best is trial 5 with value: 0.6252612350822447.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:19:52,814] Trial 10 finished with value: 0.5466912298611188 and parameters: {'learning_rate': 0.08074511050599964, 'max_iter': 495, 'max_depth': 9, 'min_samples_leaf': 20}. Best is trial 10 with value: 0.5466912298611188.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:20:27,134] Trial 11 finished with value: 0.5437125170777851 and parameters: {'learning_rate': 0.09268485612298653, 'max_iter': 494, 'max_depth': 9, 'min_samples_leaf': 20}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:21:04,904] Trial 12 finished with value: 0.5467383573269257 and parameters: {'learning_rate': 0.09593393902961081, 'max_iter': 495, 'max_depth': 9, 'min_samples_leaf': 20}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:21:40,686] Trial 13 finished with value: 0.5446085428901549 and parameters: {'learning_rate': 0.09175578608449597, 'max_iter': 494, 'max_depth': 10, 'min_samples_leaf': 20}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:22:34,805] Trial 14 finished with value: 0.547259197602094 and parameters: {'learning_rate': 0.04850340685346191, 'max_iter': 433, 'max_depth': 11, 'min_samples_leaf': 1}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:23:05,498] Trial 15 finished with value: 0.5510877904861848 and parameters: {'learning_rate': 0.04054789602646782, 'max_iter': 435, 'max_depth': 6, 'min_samples_leaf': 18}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:23:33,121] Trial 16 finished with value: 0.5474586168761344 and parameters: {'learning_rate': 0.044558749499980545, 'max_iter': 433, 'max_depth': 10, 'min_samples_leaf': 20}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:24:07,781] Trial 17 finished with value: 1.2079241253031219 and parameters: {'learning_rate': 0.0010850353712897876, 'max_iter': 331, 'max_depth': 8, 'min_samples_leaf': 10}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:24:48,827] Trial 18 finished with value: 0.5510197890179452 and parameters: {'learning_rate': 0.03159369402665945, 'max_iter': 464, 'max_depth': 11, 'min_samples_leaf': 16}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:25:28,467] Trial 19 finished with value: 0.545800141908385 and parameters: {'learning_rate': 0.06321519320862336, 'max_iter': 378, 'max_depth': 6, 'min_samples_leaf': 10}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:26:09,484] Trial 20 finished with value: 0.5673706016388607 and parameters: {'learning_rate': 0.025973855826236503, 'max_iter': 306, 'max_depth': 8, 'min_samples_leaf': 18}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:26:49,108] Trial 21 finished with value: 0.5464198428246436 and parameters: {'learning_rate': 0.06262986879100295, 'max_iter': 380, 'max_depth': 6, 'min_samples_leaf': 10}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:27:31,146] Trial 22 finished with value: 0.5453962253510064 and parameters: {'learning_rate': 0.09432641757040847, 'max_iter': 461, 'max_depth': 6, 'min_samples_leaf': 8}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:28:07,088] Trial 23 finished with value: 0.5469539913626127 and parameters: {'learning_rate': 0.09034026266471948, 'max_iter': 464, 'max_depth': 10, 'min_samples_leaf': 3}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:28:47,253] Trial 24 finished with value: 0.5604751193198324 and parameters: {'learning_rate': 0.06026584730442683, 'max_iter': 465, 'max_depth': 5, 'min_samples_leaf': 8}. Best is trial 11 with value: 0.5437125170777851.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:29:38,764] Trial 25 finished with value: 0.5424737722032118 and parameters: {'learning_rate': 0.09914644042108565, 'max_iter': 500, 'max_depth': 8, 'min_samples_leaf': 8}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:30:12,698] Trial 26 finished with value: 0.5502486208644107 and parameters: {'learning_rate': 0.03395276269302277, 'max_iter': 406, 'max_depth': 8, 'min_samples_leaf': 18}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:31:07,060] Trial 27 finished with value: 0.592809623061324 and parameters: {'learning_rate': 0.009981703993380345, 'max_iter': 500, 'max_depth': 11, 'min_samples_leaf': 15}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:31:34,428] Trial 28 finished with value: 0.5479218368226874 and parameters: {'learning_rate': 0.06279400185729733, 'max_iter': 344, 'max_depth': 9, 'min_samples_leaf': 12}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:32:03,687] Trial 29 finished with value: 0.547814445397906 and parameters: {'learning_rate': 0.04906421557513078, 'max_iter': 415, 'max_depth': 10, 'min_samples_leaf': 16}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:32:37,440] Trial 30 finished with value: 0.547814790002211 and parameters: {'learning_rate': 0.07139587360780195, 'max_iter': 470, 'max_depth': 7, 'min_samples_leaf': 19}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:33:09,148] Trial 31 finished with value: 0.5496169307764194 and parameters: {'learning_rate': 0.0918940287566381, 'max_iter': 475, 'max_depth': 5, 'min_samples_leaf': 8}. Best is trial 25 with value: 0.5424737722032118.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:33:35,311] Trial 32 finished with value: 0.5413108363334782 and parameters: {'learning_rate': 0.09436708042968521, 'max_iter': 446, 'max_depth': 8, 'min_samples_leaf': 8}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:34:00,663] Trial 33 finished with value: 0.5450172028024741 and parameters: {'learning_rate': 0.05198439621752607, 'max_iter': 441, 'max_depth': 8, 'min_samples_leaf': 6}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:34:36,581] Trial 34 finished with value: 0.6504897210181929 and parameters: {'learning_rate': 0.006535583587854047, 'max_iter': 496, 'max_depth': 7, 'min_samples_leaf': 11}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:34:58,710] Trial 35 finished with value: 0.5452139051958369 and parameters: {'learning_rate': 0.0734891170936154, 'max_iter': 401, 'max_depth': 9, 'min_samples_leaf': 4}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:35:17,293] Trial 36 finished with value: 0.5692091950214572 and parameters: {'learning_rate': 0.032861901904037656, 'max_iter': 252, 'max_depth': 8, 'min_samples_leaf': 9}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:35:49,951] Trial 37 finished with value: 0.7543234170091367 and parameters: {'learning_rate': 0.003876599379606816, 'max_iter': 448, 'max_depth': 10, 'min_samples_leaf': 12}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:36:19,627] Trial 38 finished with value: 0.5577665267336956 and parameters: {'learning_rate': 0.024807962414532054, 'max_iter': 482, 'max_depth': 9, 'min_samples_leaf': 5}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:36:47,918] Trial 39 finished with value: 0.5786192471822863 and parameters: {'learning_rate': 0.0140864109604957, 'max_iter': 420, 'max_depth': 7, 'min_samples_leaf': 14}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:37:23,471] Trial 40 finished with value: 0.5484212418245076 and parameters: {'learning_rate': 0.038651632410496184, 'max_iter': 449, 'max_depth': 12, 'min_samples_leaf': 7}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:37:54,230] Trial 41 finished with value: 0.5414804251543586 and parameters: {'learning_rate': 0.052039841618695716, 'max_iter': 447, 'max_depth': 8, 'min_samples_leaf': 6}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:38:22,327] Trial 42 finished with value: 0.544850679772958 and parameters: {'learning_rate': 0.07579898528200052, 'max_iter': 482, 'max_depth': 8, 'min_samples_leaf': 7}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:38:44,198] Trial 43 finished with value: 0.5416593315736916 and parameters: {'learning_rate': 0.09565767671899815, 'max_iter': 392, 'max_depth': 9, 'min_samples_leaf': 5}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:39:07,656] Trial 44 finished with value: 0.5477977805396995 and parameters: {'learning_rate': 0.05804203750307478, 'max_iter': 397, 'max_depth': 7, 'min_samples_leaf': 5}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:39:32,069] Trial 45 finished with value: 0.5467562589391595 and parameters: {'learning_rate': 0.07679186330245512, 'max_iter': 367, 'max_depth': 9, 'min_samples_leaf': 3}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:39:55,803] Trial 46 finished with value: 0.5496436411898343 and parameters: {'learning_rate': 0.09902919777329383, 'max_iter': 417, 'max_depth': 8, 'min_samples_leaf': 1}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:40:09,834] Trial 47 finished with value: 0.5589664209753757 and parameters: {'learning_rate': 0.07483781511193395, 'max_iter': 127, 'max_depth': 9, 'min_samples_leaf': 5}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:40:36,570] Trial 48 finished with value: 0.5459357854510214 and parameters: {'learning_rate': 0.09994731503999851, 'max_iter': 452, 'max_depth': 9, 'min_samples_leaf': 9}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:40:54,799] Trial 49 finished with value: 0.6414896957991061 and parameters: {'learning_rate': 0.04988208788070122, 'max_iter': 428, 'max_depth': 3, 'min_samples_leaf': 6}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:41:27,540] Trial 50 finished with value: 0.5473597765874942 and parameters: {'learning_rate': 0.04126952615205813, 'max_iter': 480, 'max_depth': 7, 'min_samples_leaf': 3}. Best is trial 32 with value: 0.5413108363334782.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:41:53,080] Trial 51 finished with value: 0.5409006584096521 and parameters: {'learning_rate': 0.08044476287861722, 'max_iter': 500, 'max_depth': 10, 'min_samples_leaf': 7}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:42:21,531] Trial 52 finished with value: 0.544961099589984 and parameters: {'learning_rate': 0.08019957384116758, 'max_iter': 483, 'max_depth': 11, 'min_samples_leaf': 9}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:42:49,622] Trial 53 finished with value: 0.544789495316123 and parameters: {'learning_rate': 0.06610392502228468, 'max_iter': 500, 'max_depth': 10, 'min_samples_leaf': 7}. Best is trial 51 with value: 0.5409006584096521.
# ...
#   warnings.warn(
# [I 2024-12-10 18:54:52,697] Trial 82 finished with value: 0.5724395517400469 and parameters: {'learning_rate': 0.014038796483344518, 'max_iter': 465, 'max_depth': 9, 'min_samples_leaf': 7}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:55:16,850] Trial 83 finished with value: 0.5444275980332844 and parameters: {'learning_rate': 0.09444706839036449, 'max_iter': 477, 'max_depth': 9, 'min_samples_leaf': 6}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:55:41,623] Trial 84 finished with value: 0.5500283245322344 and parameters: {'learning_rate': 0.07781894649474806, 'max_iter': 498, 'max_depth': 8, 'min_samples_leaf': 9}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:55:58,370] Trial 85 finished with value: 0.5486887330327678 and parameters: {'learning_rate': 0.09978091408542844, 'max_iter': 256, 'max_depth': 10, 'min_samples_leaf': 8}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:56:22,887] Trial 86 finished with value: 0.5476125187570139 and parameters: {'learning_rate': 0.05239241138875142, 'max_iter': 455, 'max_depth': 8, 'min_samples_leaf': 13}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:56:46,459] Trial 87 finished with value: 0.5421761609081002 and parameters: {'learning_rate': 0.06103956550365907, 'max_iter': 439, 'max_depth': 9, 'min_samples_leaf': 10}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:57:10,632] Trial 88 finished with value: 0.5437983917908354 and parameters: {'learning_rate': 0.06188592959683825, 'max_iter': 443, 'max_depth': 9, 'min_samples_leaf': 11}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:57:35,790] Trial 89 finished with value: 0.5442237511643808 and parameters: {'learning_rate': 0.07013510467903265, 'max_iter': 482, 'max_depth': 12, 'min_samples_leaf': 5}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:58:05,984] Trial 90 finished with value: 0.5487702945119282 and parameters: {'learning_rate': 0.046734795361632664, 'max_iter': 414, 'max_depth': 10, 'min_samples_leaf': 10}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:58:29,753] Trial 91 finished with value: 0.5440242200033072 and parameters: {'learning_rate': 0.08892638268046375, 'max_iter': 435, 'max_depth': 9, 'min_samples_leaf': 7}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:58:56,055] Trial 92 finished with value: 0.5442878756920343 and parameters: {'learning_rate': 0.057678176250500035, 'max_iter': 469, 'max_depth': 9, 'min_samples_leaf': 9}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:59:23,861] Trial 93 finished with value: 0.5426915112756258 and parameters: {'learning_rate': 0.07769595631341107, 'max_iter': 486, 'max_depth': 8, 'min_samples_leaf': 12}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 18:59:45,524] Trial 94 finished with value: 0.5450209649538571 and parameters: {'learning_rate': 0.06455275042108505, 'max_iter': 382, 'max_depth': 8, 'min_samples_leaf': 10}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 19:00:09,217] Trial 95 finished with value: 0.5439306289024445 and parameters: {'learning_rate': 0.09000627600748919, 'max_iter': 403, 'max_depth': 10, 'min_samples_leaf': 7}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 19:00:38,163] Trial 96 finished with value: 0.5458254777338002 and parameters: {'learning_rate': 0.07594015278975036, 'max_iter': 500, 'max_depth': 7, 'min_samples_leaf': 8}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 19:01:01,214] Trial 97 finished with value: 0.5446223400941355 and parameters: {'learning_rate': 0.09065842821035612, 'max_iter': 453, 'max_depth': 9, 'min_samples_leaf': 4}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 19:01:24,673] Trial 98 finished with value: 0.5480168999789997 and parameters: {'learning_rate': 0.05316796019853926, 'max_iter': 421, 'max_depth': 8, 'min_samples_leaf': 6}. Best is trial 51 with value: 0.5409006584096521.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_5499/1914931631.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-10 19:01:55,705] Trial 99 finished with value: 1.050521345237171 and parameters: {'learning_rate': 0.0014171963584150812, 'max_iter': 448, 'max_depth': 9, 'min_samples_leaf': 9}. Best is trial 51 with value: 0.5409006584096521.
# Best trial:
#   RMSE: 0.5409006584096521
#   Best hyperparameters:
#     learning_rate: 0.08044476287861722
#     max_iter: 500
#     max_depth: 10
#     min_samples_leaf: 7
# Final validation RMSE: 0.54
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
final_predictions = final_model.predict(test_set)

# %%
# Prepare submission
output_df = pd.DataFrame({
    'Id': test_set.index,
    'log_bike_count': final_predictions
})

# Format log_bike_count:
output_df['log_bike_count'] = output_df['log_bike_count'].map(lambda x: f"{x:.4f}")

# Save to CSV:
output_df.to_csv('vs_sub_full_dataset_HGB_v3.csv', index=False)
print("Predictions saved to 'vs_sub_full_dataset_HGB_v3.csv'.")
# Out:
# Predictions saved to 'vs_sub_full_dataset_HGB_v3.csv'.
