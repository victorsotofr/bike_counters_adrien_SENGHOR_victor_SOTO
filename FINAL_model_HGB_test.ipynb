# %%
import utils
import pandas as pd
import numpy as np
import FINAL_FeatureEngineering

# %%
X, y = utils.get_train_data()

# %%
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import HistGradientBoostingRegressor

from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler

# DATA PREPROCESSING
# ==============================================================================
numeric_features = [### DATA
                    # Relative to dates
                    'year',
                    'season_sin',
                    'season_cos',
                    'month_sin',
                    'month_cos',
                    'weekday_sin',
                    'weekday_cos',
                    'hour_sin',
                    'hour_cos',
                    'is_weekend',
                    'is_holiday',
                    'is_covid',
                    # Relative to location:
                    'site_id',
                    'latitude',
                    'longitude',

                    ### EXTERNAL DATA
                    't',
                    'raf10',
                    'etat_sol',
                    'nnuage1', 
                    'rr12', 
                    'rr24',
                    'cl', 
                    'ssfrai', 
                    'w2'
                    ]


preprocessor = ColumnTransformer(
    [('standard-scaler', StandardScaler(), numeric_features)],
    remainder='drop'
    )

# We create the full modeling pipeline:
model = make_pipeline(
    FINAL_FeatureEngineering.FeatureEngineering(),
    preprocessor,
    HistGradientBoostingRegressor(learning_rate=0.05, max_iter=300, max_depth=10) # default values
)

# %%
### TRAIN_TEST_split and RMSE measures:
def train_test_split_temporal(X, y, delta_threshold="30 days"):
    
    cutoff_date = X["date"].max() - pd.Timedelta(delta_threshold)
    mask = (X["date"] <= cutoff_date)
    X_train, X_valid = X.loc[mask], X.loc[~mask]
    y_train, y_valid = y[mask], y[~mask]

    return X_train, y_train, X_valid, y_valid

X_train, y_train, X_valid, y_valid = train_test_split_temporal(X, y)

# %%
model.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('featureengineering',
#                  <FINAL_FeatureEngineering.FeatureEngineering object at 0x12edccd30>),
#                 ('columntransformer',
#                  ColumnTransformer(transformers=[('standard-scaler',
#                                                   StandardScaler(),
#                                                   ['year', 'season_sin',
#                                                    'season_cos', 'month_sin',
#                                                    'month_cos', 'weekday_sin',
#                                                    'weekday_cos', 'hour_sin',
#                                                    'hour_cos', 'is_weekend',
#                                                    'is_holiday', 'is_covid',
#                                                    'site_id', 'latitude',
#                                                    'longitude', 't', 'raf10',
#                                                    'etat_sol', 'nnuage1',
#                                                    'rr12', 'rr24', 'cl',
#                                                    'ssfrai', 'w2'])])),
#                 ('histgradientboostingregressor',
#                  HistGradientBoostingRegressor(learning_rate=0.05, max_depth=10,
#                                                max_iter=300))])

# %%
from sklearn.metrics import mean_squared_error

y_train_pred = model.predict(X_train)
y_valid_pred = model.predict(X_valid)

# Calculate and print RMSE for train and validation sets
print(f"Train set, RMSE={mean_squared_error(y_train, y_train_pred, squared=False):.2f}")
print(f"Validation set, RMSE={mean_squared_error(y_valid, y_valid_pred, squared=False):.2f}")
# Out:
# Train set, RMSE=0.58
# Validation set, RMSE=0.55
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
test_set = pd.read_parquet("./data/final_test.parquet")

# %%
predictions = model.predict(test_set)

# %%
# Prepare submission
output_df = pd.DataFrame({
    'Id': test_set.index,
    'log_bike_count': predictions
})

# Format log_bike_count:
output_df['log_bike_count'] = output_df['log_bike_count'].map(lambda x: f"{x:.4f}")

# Save to CSV:
output_df.to_csv('FINAL_predictions_HGB.csv', index=False)
print("Predictions saved to 'FINAL_predictions_HGB.csv'.")
# Out:
# Predictions saved to 'FINAL_predictions_HGB.csv'.

# %% [markdown]
# # __OPTUNA__

# %%
import optuna

# %%
def objective(trial):
    # Suggest hyperparameters
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
    max_iter = trial.suggest_int('max_iter', 100, 500)
    max_depth = trial.suggest_int('max_depth', 3, 12)
    min_samples_leaf = trial.suggest_int('min_samples_leaf', 1, 20)
    
    # Create a pipeline with the suggested hyperparameters
    model = make_pipeline(
        FINAL_FeatureEngineering.FeatureEngineering(),
        preprocessor,
        HistGradientBoostingRegressor(
            learning_rate=learning_rate,
            max_iter=max_iter,
            max_depth=max_depth,
            min_samples_leaf=min_samples_leaf
        )
    )
    
    # Split your data into training and validation sets
    X_train, y_train, X_valid, y_valid = train_test_split_temporal(X, y)

    # Fit the model
    model.fit(X_train, y_train)
    
    # Make predictions and calculate the RMSE
    y_valid_pred = model.predict(X_valid)
    rmse = mean_squared_error(y_valid, y_valid_pred, squared=False)
    
    return rmse  # We want to minimize RMSE

# Run Optuna optimization
study = optuna.create_study(direction='minimize')  # Minimize the objective
study.optimize(objective, n_trials=100)  # Run for 100 trials

# Print the best parameters
print("Best trial:")
trial = study.best_trial

print(f"  RMSE: {trial.value}")
print("  Best hyperparameters:")
for key, value in trial.params.items():
    print(f"    {key}: {value}")

# After optimization, you can use the best hyperparameters to train your final model
best_params = trial.params
final_model = make_pipeline(
    FINAL_FeatureEngineering.FeatureEngineering(),
    preprocessor,
    HistGradientBoostingRegressor(
        learning_rate=best_params['learning_rate'],
        max_iter=best_params['max_iter'],
        max_depth=best_params['max_depth'],
        min_samples_leaf=best_params['min_samples_leaf']
    )
)

# Fit the final model on the full training set
final_model.fit(X_train, y_train)

# Make predictions on the validation set
y_valid_pred = final_model.predict(X_valid)

# Evaluate the model
print(f"Final validation RMSE: {mean_squared_error(y_valid, y_valid_pred, squared=False):.2f}")
# Out:
# [I 2024-12-11 18:59:39,572] A new study created in memory with name: no-name-b1617526-9788-42a4-ade5-ebce10afea91
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:00:22,630] Trial 0 finished with value: 1.1624755065724357 and parameters: {'learning_rate': 0.00166312444770148, 'max_iter': 255, 'max_depth': 10, 'min_samples_leaf': 13}. Best is trial 0 with value: 1.1624755065724357.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:00:50,751] Trial 1 finished with value: 0.591778374134364 and parameters: {'learning_rate': 0.02557817685283306, 'max_iter': 221, 'max_depth': 6, 'min_samples_leaf': 6}. Best is trial 1 with value: 0.591778374134364.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:01:30,838] Trial 2 finished with value: 0.5481665975295039 and parameters: {'learning_rate': 0.06033924192809777, 'max_iter': 402, 'max_depth': 9, 'min_samples_leaf': 10}. Best is trial 2 with value: 0.5481665975295039.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:02:05,858] Trial 3 finished with value: 1.2541331148388166 and parameters: {'learning_rate': 0.0017559895138206485, 'max_iter': 160, 'max_depth': 11, 'min_samples_leaf': 8}. Best is trial 2 with value: 0.5481665975295039.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:02:35,840] Trial 4 finished with value: 0.6414365150457801 and parameters: {'learning_rate': 0.018244987990375133, 'max_iter': 178, 'max_depth': 11, 'min_samples_leaf': 16}. Best is trial 2 with value: 0.5481665975295039.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:02:52,714] Trial 5 finished with value: 1.3264753496196766 and parameters: {'learning_rate': 0.0013388455147944618, 'max_iter': 184, 'max_depth': 3, 'min_samples_leaf': 1}. Best is trial 2 with value: 0.5481665975295039.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:03:34,195] Trial 6 finished with value: 0.5439504679620437 and parameters: {'learning_rate': 0.07426122627682698, 'max_iter': 466, 'max_depth': 12, 'min_samples_leaf': 7}. Best is trial 6 with value: 0.5439504679620437.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:03:53,337] Trial 7 finished with value: 0.7165101590779723 and parameters: {'learning_rate': 0.019360685862709653, 'max_iter': 108, 'max_depth': 8, 'min_samples_leaf': 11}. Best is trial 6 with value: 0.5439504679620437.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:04:16,106] Trial 8 finished with value: 1.2385564943528566 and parameters: {'learning_rate': 0.0022812273962416335, 'max_iter': 133, 'max_depth': 12, 'min_samples_leaf': 11}. Best is trial 6 with value: 0.5439504679620437.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:04:40,843] Trial 9 finished with value: 0.7220754864236069 and parameters: {'learning_rate': 0.010630129924600037, 'max_iter': 189, 'max_depth': 10, 'min_samples_leaf': 5}. Best is trial 6 with value: 0
. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:24:45,395] Trial 51 finished with value: 0.5433606778326141 and parameters: {'learning_rate': 0.055812505914702874, 'max_iter': 484, 'max_depth': 8, 'min_samples_leaf': 20}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:25:08,798] Trial 52 finished with value: 0.5457319199256742 and parameters: {'learning_rate': 0.0839798876494595, 'max_iter': 453, 'max_depth': 7, 'min_samples_leaf': 18}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# ...
#   warnings.warn(
# [I 2024-12-11 19:36:47,561] Trial 82 finished with value: 0.5500538279588227 and parameters: {'learning_rate': 0.0352180232426043, 'max_iter': 491, 'max_depth': 8, 'min_samples_leaf': 11}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:37:12,978] Trial 83 finished with value: 0.5450087002888367 and parameters: {'learning_rate': 0.05096653485518582, 'max_iter': 477, 'max_depth': 7, 'min_samples_leaf': 9}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:37:37,719] Trial 84 finished with value: 0.5412406576956958 and parameters: {'learning_rate': 0.08941262399064731, 'max_iter': 430, 'max_depth': 6, 'min_samples_leaf': 19}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:38:05,332] Trial 85 finished with value: 0.5437997266869535 and parameters: {'learning_rate': 0.09268043794494825, 'max_iter': 435, 'max_depth': 6, 'min_samples_leaf': 6}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:38:32,025] Trial 86 finished with value: 0.5461688105732878 and parameters: {'learning_rate': 0.07564610938101281, 'max_iter': 459, 'max_depth': 6, 'min_samples_leaf': 12}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:38:55,984] Trial 87 finished with value: 0.5549573705674755 and parameters: {'learning_rate': 0.06843540876384072, 'max_iter': 427, 'max_depth': 5, 'min_samples_leaf': 19}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:39:21,415] Trial 88 finished with value: 0.5420838507834027 and parameters: {'learning_rate': 0.09931588830155953, 'max_iter': 480, 'max_depth': 7, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:39:46,528] Trial 89 finished with value: 0.5425665505530646 and parameters: {'learning_rate': 0.08936615362616002, 'max_iter': 490, 'max_depth': 7, 'min_samples_leaf': 4}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:40:07,317] Trial 90 finished with value: 0.5433715767053542 and parameters: {'learning_rate': 0.07985402112300172, 'max_iter': 353, 'max_depth': 7, 'min_samples_leaf': 2}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:40:31,300] Trial 91 finished with value: 0.5434131351337187 and parameters: {'learning_rate': 0.09801829066495045, 'max_iter': 470, 'max_depth': 6, 'min_samples_leaf': 1}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:40:56,090] Trial 92 finished with value: 0.5437803531237192 and parameters: {'learning_rate': 0.09974616138663037, 'max_iter': 494, 'max_depth': 6, 'min_samples_leaf': 8}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:41:21,202] Trial 93 finished with value: 0.5459583468707971 and parameters: {'learning_rate': 0.08539556595814168, 'max_iter': 479, 'max_depth': 7, 'min_samples_leaf': 4}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:41:47,344] Trial 94 finished with value: 0.5462830944842421 and parameters: {'learning_rate': 0.06822935349617977, 'max_iter': 481, 'max_depth': 7, 'min_samples_leaf': 3}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:42:11,735] Trial 95 finished with value: 0.5444760028335935 and parameters: {'learning_rate': 0.07686310708062978, 'max_iter': 453, 'max_depth': 6, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:42:50,999] Trial 96 finished with value: 0.5555970383605932 and parameters: {'learning_rate': 0.060247246074789276, 'max_iter': 468, 'max_depth': 5, 'min_samples_leaf': 19}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:43:25,544] Trial 97 finished with value: 0.5466642468419347 and parameters: {'learning_rate': 0.09090302502535416, 'max_iter': 499, 'max_depth': 6, 'min_samples_leaf': 5}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:44:08,827] Trial 98 finished with value: 0.5419129253800571 and parameters: {'learning_rate': 0.07099793278135487, 'max_iter': 462, 'max_depth': 6, 'min_samples_leaf': 6}. Best is trial 12 with value: 0.5389575323761595.
# /var/folders/kw/8v5sq5616c9bt_3ddzy97nq40000gn/T/ipykernel_10181/2493503855.py:3: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-3, 1e-1)
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# [I 2024-12-11 19:44:44,274] Trial 99 finished with value: 0.5443711619412006 and parameters: {'learning_rate': 0.06548880773215285, 'max_iter': 441, 'max_depth': 7, 'min_samples_leaf': 6}. Best is trial 12 with value: 0.5389575323761595.
# Best trial:
#   RMSE: 0.5389575323761595
#   Best hyperparameters:
#     learning_rate: 0.09610866770801975
#     max_iter: 484
#     max_depth: 6
#     min_samples_leaf: 20
# Final validation RMSE: 0.55
# /Applications/anaconda3/envs/bikes-count/lib/python3.10/site-packages/sklearn/metrics/_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
